# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
print(dt.now())
# Out:
# 2021-08-06 21:20:15.144272

# %%
targetSite = 'https://music.bugs.co.kr/chart'
request = requests.get(targetSite)
# print(request)
html = request.text
# print(html)
soup = BeautifulSoup(html, 'html.parser')
# print(soup)

# %%
# 노래 제목 크롤링
# 노래 제목은 'class' 속성이 'title'인 <p> 태그 내부에 있다.
titles = soup.findAll('p', {'class': 'title'})
# print(titles)
# print(len(titles))
for title in titles:
    # print(title.text.strip())
    # print(title.text.split('\n')[1])
    print(title.text.strip().split('\n')[0])
# Out:
# You can't sit with us
# 낙하 (with 아이유)
# 너에게
# Permission to Dance
# STAY
# 신호등
# Next Level
# 비가 오는 날엔 (2021)
# Weekend
# DUMB DUMB
# 연애소설(2021)
# Butter
# 전쟁터 (with 이선희)
# 바라만 본다
# 이젠 잊기로 해요 (Drama Ver.)
# Bad Habits
# 좋아좋아
# Dun Dun Dance
# 벌써 일년 (Drama Ver.)
# 외딴섬 로맨틱
# 고백
# Alcohol-Free
# Peaches (feat. Daniel Caesar, Giveon)
# 라일락
# 헤픈 우연
# 째깍 째깍 째깍 (with Beenzino)
# OHAYO MY NIGHT
# 넌 좋은 사람
# 슈퍼스타
# BENCH (with Zion.T)
# SUNNY
# ASAP
# Dolphin
# 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# Dynamite
# 비와 당신
# I'm Gonna Love You (Feat. 원슈타인)
# Stupid love song (with Crush)
# 아마도 어제
# Off My Face
# Kiss Me More (feat. SZA)
# 치맛바람 (Chi Mat Ba Ram)
# Leave Before You Love Me
# 롤린 (Rollin')
# 나를 아는 사람
# Tiny Riot
# 가을 우체국 앞에서
# Loving You Girl (feat. Hkeem)
# 그대 한 사람 (낮에 뜨는 달 X 산들)
# Timeless
# 내 손을 잡아
# 나는 너 좋아
# 하루만 더
# 어푸 (Ah puh)
# 보고 싶단 말이야
# 안녕 (Hello)
# Savage Love (Laxed - Siren Beat) (BTS Remix)
# Black Mamba
# 한여름밤의 꿀 : 다시 여름
# WE GO
# 운전만해 (We Ride)
# 뚫고 지나가요
# 상상더하기
# Celebrity
# 다시 사랑할 수 있을까
# Lovesick Girls
# 벌써 일년
# 다정히 내 이름을 부르면
# 밤이 되니까
# Call
# 추적이는 여름 비가 되어
# EVEREST (with Sam Kim)
# 에잇(Prod.&Feat. SUGA of BTS)
# 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 맞짱 (with 잔나비 최정훈)
# 러브 (Prod. 로코베리)
# 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
# Take My Breath
# Hello Future
# Rose
# Blueming
# Leave The Door Open
# 6분의1
# Life Goes On
# 주저하는 연인들을 위해
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 멜로디
# Beautiful
# 난 너를 사랑해
# Narcissism
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 상상더하기
# 과제곡 (교수님 죄송합니다)
# parachute
# 흑백영화 (Prod. BOYCOLD)
# Coin
# 별빛 같은 나의 사랑아
# 마.피.아. In the morning
# 내사람: Partner For Life
# 내 입술 따뜻한 커피처럼

# %%
# 아티스트 크롤링
# 가수 이름은 'class' 속성이 'artist'인 <p> 태그 내부에 있다.
artists = soup.findAll('p', {'class': 'artist'})
# print(artists)
# print(len(artists))
for artist in artists:
    # print(artist.text.strip())
    # print(artist.text.split('\n')[1])
    print(artist.text.strip().split('\n')[0])
# Out:
# 선미
# AKMU(악뮤)
# 유연석
# 방탄소년단
# The Kid LAROI
# 이무진
# aespa
# 헤이즈(Heize)
# 태연 (TAEYEON)
# 전소미
# 가비엔제이(Gavy N.J.)
# 방탄소년단
# AKMU(악뮤)
# MSG워너비(M.O.M)
# 미도와 파라솔
# Ed Sheeran(에드 시런)
# 조정석
# 오마이걸(OH MY GIRL)
# 미도와 파라솔
# 잔나비
# 장범준
# TWICE (트와이스)
# Justin Bieber(저스틴 비버)
# 아이유(IU)
# 헤이즈(Heize)
# AKMU(악뮤)
# 디핵(D-Hack)
# SG워너비
# 미도와 파라솔
# AKMU(악뮤)
# 선미
# STAYC(스테이씨)
# 오마이걸(OH MY GIRL)
# 에픽하이 (EPIK HIGH)
# 방탄소년단
# 이무진
# 디오 (D.O.)
# AKMU(악뮤)
# 비와이(BewhY)
# Justin Bieber(저스틴 비버)
# Doja Cat(도자 캣)
# 브레이브걸스(Brave Girls)
# Marshmello(마시멜로)
# 브레이브걸스(Brave Girls)
# MSG워너비(정상동기)
# Sam Ryder
# 김대명
# Peder Elias
# 산들
# SG워너비
# 아이유(IU)
# 장범준
# 빅마마(Big Mama)
# 아이유(IU)
# 펀치 (Punch)
# 조이 (JOY)
# Jawsh 685
# aespa
# San E(산이)
# 프로미스나인
# 브레이브걸스(Brave Girls)
# DAY6 (Even of Day)
# 라붐(LABOUM)
# 아이유(IU)
# 백지영
# BLACKPINK
# 브라운 아이즈(Brown Eyes)
# 경서예지
# 원슈타인
# 선미
# 장범준
# AKMU(악뮤)
# 아이유(IU)
# 방탄소년단
# AKMU(악뮤)
# 로꼬
# 호미들
# The Weeknd(위켄드)
# NCT DREAM
# 디오 (D.O.)
# 아이유(IU)
# Bruno Mars(브루노 마스)
# 선미
# 방탄소년단
# 잔나비
# AKMU(악뮤)
# ASH ISLAND
# Anne-Marie(앤 마리)
# MSG워너비
# 선미
# 장범준
# MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인)
# 이무진
# John K
# 릴러말즈 (Leellamarz)
# 아이유(IU)
# 임영웅
# ITZY (있지)
# SG워너비
# 청하

# %%
print(dt.now())
for i in range(len(titles)):
    title = titles[i].text.strip().split('\n')[0]
    artist = artists[i].text.strip().split('\n')[0]
    print('{0:3d}등 {1} - {2}'.format(i + 1, artist, title))
# Out:
# 2021-08-06 21:20:16.137589
#   1등 선미 - You can't sit with us
#   2등 AKMU(악뮤) - 낙하 (with 아이유)
#   3등 유연석 - 너에게
#   4등 방탄소년단 - Permission to Dance
#   5등 The Kid LAROI - STAY
#   6등 이무진 - 신호등
#   7등 aespa - Next Level
#   8등 헤이즈(Heize) - 비가 오는 날엔 (2021)
#   9등 태연 (TAEYEON) - Weekend
#  10등 전소미 - DUMB DUMB
#  11등 가비엔제이(Gavy N.J.) - 연애소설(2021)
#  12등 방탄소년단 - Butter
#  13등 AKMU(악뮤) - 전쟁터 (with 이선희)
#  14등 MSG워너비(M.O.M) - 바라만 본다
#  15등 미도와 파라솔 - 이젠 잊기로 해요 (Drama Ver.)
#  16등 Ed Sheeran(에드 시런) - Bad Habits
#  17등 조정석 - 좋아좋아
#  18등 오마이걸(OH MY GIRL) - Dun Dun Dance
#  19등 미도와 파라솔 - 벌써 일년 (Drama Ver.)
#  20등 잔나비 - 외딴섬 로맨틱
#  21등 장범준 - 고백
#  22등 TWICE (트와이스) - Alcohol-Free
#  23등 Justin Bieber(저스틴 비버) - Peaches (feat. Daniel Caesar, Giveon)
#  24등 아이유(IU) - 라일락
#  25등 헤이즈(Heize) - 헤픈 우연
#  26등 AKMU(악뮤) - 째깍 째깍 째깍 (with Beenzino)
#  27등 디핵(D-Hack) - OHAYO MY NIGHT
#  28등 SG워너비 - 넌 좋은 사람
#  29등 미도와 파라솔 - 슈퍼스타
#  30등 AKMU(악뮤) - BENCH (with Zion.T)
#  31등 선미 - SUNNY
#  32등 STAYC(스테이씨) - ASAP
#  33등 오마이걸(OH MY GIRL) - Dolphin
#  34등 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  35등 방탄소년단 - Dynamite
#  36등 이무진 - 비와 당신
#  37등 디오 (D.O.) - I'm Gonna Love You (Feat. 원슈타인)
#  38등 AKMU(악뮤) - Stupid love song (with Crush)
#  39등 비와이(BewhY) - 아마도 어제
#  40등 Justin Bieber(저스틴 비버) - Off My Face
#  41등 Doja Cat(도자 캣) - Kiss Me More (feat. SZA)
#  42등 브레이브걸스(Brave Girls) - 치맛바람 (Chi Mat Ba Ram)
#  43등 Marshmello(마시멜로) - Leave Before You Love Me
#  44등 브레이브걸스(Brave Girls) - 롤린 (Rollin')
#  45등 MSG워너비(정상동기) - 나를 아는 사람
#  46등 Sam Ryder - Tiny Riot
#  47등 김대명 - 가을 우체국 앞에서
#  48등 Peder Elias - Loving You Girl (feat. Hkeem)
#  49등 산들 - 그대 한 사람 (낮에 뜨는 달 X 산들)
#  50등 SG워너비 - Timeless
#  51등 아이유(IU) - 내 손을 잡아
#  52등 장범준 - 나는 너 좋아
#  53등 빅마마(Big Mama) - 하루만 더
#  54등 아이유(IU) - 어푸 (Ah puh)
#  55등 펀치 (Punch) - 보고 싶단 말이야
#  56등 조이 (JOY) - 안녕 (Hello)
#  57등 Jawsh 685 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  58등 aespa - Black Mamba
#  59등 San E(산이) - 한여름밤의 꿀 : 다시 여름
#  60등 프로미스나인 - WE GO
#  61등 브레이브걸스(Brave Girls) - 운전만해 (We Ride)
#  62등 DAY6 (Even of Day) - 뚫고 지나가요
#  63등 라붐(LABOUM) - 상상더하기
#  64등 아이유(IU) - Celebrity
#  65등 백지영 - 다시 사랑할 수 있을까
#  66등 BLACKPINK - Lovesick Girls
#  67등 브라운 아이즈(Brown Eyes) - 벌써 일년
#  68등 경서예지 - 다정히 내 이름을 부르면
#  69등 원슈타인 - 밤이 되니까
#  70등 선미 - Call
#  71등 장범준 - 추적이는 여름 비가 되어
#  72등 AKMU(악뮤) - EVEREST (with Sam Kim)
#  73등 아이유(IU) - 에잇(Prod.&Feat. SUGA of BTS)
#  74등 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  75등 AKMU(악뮤) - 맞짱 (with 잔나비 최정훈)
#  76등 로꼬 - 러브 (Prod. 로코베리)
#  77등 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
#  78등 The Weeknd(위켄드) - Take My Breath
#  79등 NCT DREAM - Hello Future
#  80등 디오 (D.O.) - Rose
#  81등 아이유(IU) - Blueming
#  82등 Bruno Mars(브루노 마스) - Leave The Door Open
#  83등 선미 - 6분의1
#  84등 방탄소년단 - Life Goes On
#  85등 잔나비 - 주저하는 연인들을 위해
#  86등 AKMU(악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  87등 ASH ISLAND - 멜로디
#  88등 Anne-Marie(앤 마리) - Beautiful
#  89등 MSG워너비 - 난 너를 사랑해
#  90등 선미 - Narcissism
#  91등 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  92등 MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인) - 상상더하기
#  93등 이무진 - 과제곡 (교수님 죄송합니다)
#  94등 John K - parachute
#  95등 릴러말즈 (Leellamarz) - 흑백영화 (Prod. BOYCOLD)
#  96등 아이유(IU) - Coin
#  97등 임영웅 - 별빛 같은 나의 사랑아
#  98등 ITZY (있지) - 마.피.아. In the morning
#  99등 SG워너비 - 내사람: Partner For Life
# 100등 청하 - 내 입술 따뜻한 커피처럼

# %%
# 크롤링한 결과를 텍스트 파일에 저장한다.
file = open('./data/bugsTOP100.txt', 'w')
# UnicodeEncodeError: 'cp949' codec can't encode character '\xf1' in position 29: illegal multibyte sequence
# 크롤링 데이터를 텍스트 파일에 저장하려는 경우 위와 같이 한글 인코딩 문제로 UnicodeEncodeError가 발생될 수 있다.
# UnicodeEncodeError 에러가 발생되면 아래와 같이 파일을 open 하면 된다.
# file = open('./data/bugsTOP100.txt', 'w', -1, 'UTF-8')

file.write('{} 현재 Bugs 뮤직 실시간 TOP 100\n'.format(dt.now()))
for i in range(len(titles)):
    title = titles[i].text.strip().split('\n')[0]
    artist = artists[i].text.strip().split('\n')[0]
    data = '{0:3d}등 {1} - {2}'.format(i + 1, artist, title)
    file.write(data + '\n')
file.close()
print('bugsTOP100.txt 파일에 쓰기 완료')
# Out:
# bugsTOP100.txt 파일에 쓰기 완료

# %%
# 텍스트 파일에 저장된 데이터를 읽어서 출력한다.
try:
    file = open('./data/bugsTOP100.txt', 'r')
    # readlines() 메소드는 텍스트 파일의 내용 전체를 한꺼번에 읽어서 리스트로 얻어온다.
    lines = file.readlines()
    for line in lines:
        print(line.strip())
except FileNotFoundError:
    print('bugsTOP100.txt 파일이 디스크에 없습니다.')
# Out:
# 2021-08-06 21:20:16.185591 현재 Bugs 뮤직 실시간 TOP 100
# 1등 선미 - You can't sit with us
# 2등 AKMU(악뮤) - 낙하 (with 아이유)
# 3등 유연석 - 너에게
# 4등 방탄소년단 - Permission to Dance
# 5등 The Kid LAROI - STAY
# 6등 이무진 - 신호등
# 7등 aespa - Next Level
# 8등 헤이즈(Heize) - 비가 오는 날엔 (2021)
# 9등 태연 (TAEYEON) - Weekend
# 10등 전소미 - DUMB DUMB
# 11등 가비엔제이(Gavy N.J.) - 연애소설(2021)
# 12등 방탄소년단 - Butter
# 13등 AKMU(악뮤) - 전쟁터 (with 이선희)
# 14등 MSG워너비(M.O.M) - 바라만 본다
# 15등 미도와 파라솔 - 이젠 잊기로 해요 (Drama Ver.)
# 16등 Ed Sheeran(에드 시런) - Bad Habits
# 17등 조정석 - 좋아좋아
# 18등 오마이걸(OH MY GIRL) - Dun Dun Dance
# 19등 미도와 파라솔 - 벌써 일년 (Drama Ver.)
# 20등 잔나비 - 외딴섬 로맨틱
# 21등 장범준 - 고백
# 22등 TWICE (트와이스) - Alcohol-Free
# 23등 Justin Bieber(저스틴 비버) - Peaches (feat. Daniel Caesar, Giveon)
# 24등 아이유(IU) - 라일락
# 25등 헤이즈(Heize) - 헤픈 우연
# 26등 AKMU(악뮤) - 째깍 째깍 째깍 (with Beenzino)
# 27등 디핵(D-Hack) - OHAYO MY NIGHT
# 28등 SG워너비 - 넌 좋은 사람
# 29등 미도와 파라솔 - 슈퍼스타
# 30등 AKMU(악뮤) - BENCH (with Zion.T)
# 31등 선미 - SUNNY
# 32등 STAYC(스테이씨) - ASAP
# 33등 오마이걸(OH MY GIRL) - Dolphin
# 34등 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 35등 방탄소년단 - Dynamite
# 36등 이무진 - 비와 당신
# 37등 디오 (D.O.) - I'm Gonna Love You (Feat. 원슈타인)
# 38등 AKMU(악뮤) - Stupid love song (with Crush)
# 39등 비와이(BewhY) - 아마도 어제
# 40등 Justin Bieber(저스틴 비버) - Off My Face
# 41등 Doja Cat(도자 캣) - Kiss Me More (feat. SZA)
# 42등 브레이브걸스(Brave Girls) - 치맛바람 (Chi Mat Ba Ram)
# 43등 Marshmello(마시멜로) - Leave Before You Love Me
# 44등 브레이브걸스(Brave Girls) - 롤린 (Rollin')
# 45등 MSG워너비(정상동기) - 나를 아는 사람
# 46등 Sam Ryder - Tiny Riot
# 47등 김대명 - 가을 우체국 앞에서
# 48등 Peder Elias - Loving You Girl (feat. Hkeem)
# 49등 산들 - 그대 한 사람 (낮에 뜨는 달 X 산들)
# 50등 SG워너비 - Timeless
# 51등 아이유(IU) - 내 손을 잡아
# 52등 장범준 - 나는 너 좋아
# 53등 빅마마(Big Mama) - 하루만 더
# 54등 아이유(IU) - 어푸 (Ah puh)
# 55등 펀치 (Punch) - 보고 싶단 말이야
# 56등 조이 (JOY) - 안녕 (Hello)
# 57등 Jawsh 685 - Savage Love (Laxed - Siren Beat) (BTS Remix)
# 58등 aespa - Black Mamba
# 59등 San E(산이) - 한여름밤의 꿀 : 다시 여름
# 60등 프로미스나인 - WE GO
# 61등 브레이브걸스(Brave Girls) - 운전만해 (We Ride)
# 62등 DAY6 (Even of Day) - 뚫고 지나가요
# 63등 라붐(LABOUM) - 상상더하기
# 64등 아이유(IU) - Celebrity
# 65등 백지영 - 다시 사랑할 수 있을까
# 66등 BLACKPINK - Lovesick Girls
# 67등 브라운 아이즈(Brown Eyes) - 벌써 일년
# 68등 경서예지 - 다정히 내 이름을 부르면
# 69등 원슈타인 - 밤이 되니까
# 70등 선미 - Call
# 71등 장범준 - 추적이는 여름 비가 되어
# 72등 AKMU(악뮤) - EVEREST (with Sam Kim)
# 73등 아이유(IU) - 에잇(Prod.&Feat. SUGA of BTS)
# 74등 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 75등 AKMU(악뮤) - 맞짱 (with 잔나비 최정훈)
# 76등 로꼬 - 러브 (Prod. 로코베리)
# 77등 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
# 78등 The Weeknd(위켄드) - Take My Breath
# 79등 NCT DREAM - Hello Future
# 80등 디오 (D.O.) - Rose
# 81등 아이유(IU) - Blueming
# 82등 Bruno Mars(브루노 마스) - Leave The Door Open
# 83등 선미 - 6분의1
# 84등 방탄소년단 - Life Goes On
# 85등 잔나비 - 주저하는 연인들을 위해
# 86등 AKMU(악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 87등 ASH ISLAND - 멜로디
# 88등 Anne-Marie(앤 마리) - Beautiful
# 89등 MSG워너비 - 난 너를 사랑해
# 90등 선미 - Narcissism
# 91등 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 92등 MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인) - 상상더하기
# 93등 이무진 - 과제곡 (교수님 죄송합니다)
# 94등 John K - parachute
# 95등 릴러말즈 (Leellamarz) - 흑백영화 (Prod. BOYCOLD)
# 96등 아이유(IU) - Coin
# 97등 임영웅 - 별빛 같은 나의 사랑아
# 98등 ITZY (있지) - 마.피.아. In the morning
# 99등 SG워너비 - 내사람: Partner For Life
# 100등 청하 - 내 입술 따뜻한 커피처럼
