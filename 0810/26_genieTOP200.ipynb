# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt
import time

# %%
# 타겟 사이트 주소 만들기
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210806&hh=21&rtm=Y&pg=1 =>   1 ~  50
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210806&hh=21&rtm=Y&pg=2 =>  51 ~ 100
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210806&hh=21&rtm=Y&pg=3 => 101 ~ 150
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210806&hh=21&rtm=Y&pg=4 => 151 ~ 200
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210806&hh=21&rtm=Y&pg='
for i in range(1, 5):
    # print(url + str(i))
    print('{}{}'.format(url, i))
# Out:
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210806&hh=21&rtm=Y&pg=1
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210806&hh=21&rtm=Y&pg=2
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210806&hh=21&rtm=Y&pg=3
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210806&hh=21&rtm=Y&pg=4

# %%
# 노래 제목 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210806&hh=21&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    # print(request)
    html = request.text
    # print(html)
    soup = BeautifulSoup(html, 'html.parser')
    # print(soup)
    
    # 노래 제목은 'class' 속성이 'title ellipsis'인 <a> 태그 내부에 있다.
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    # print(titles)
    # print(len(titles))
    
    i = 0
    for title in titles:
        i += 1
        # print(i, title.text.strip())
        # print(i, title.text.split('\n')[-1].strip())
        print(i, title.text.strip().split('\n')[0])
# Out:
# 1 신호등
# 2 낙하 (With 아이유)
# 3 바라만 본다
# 4 Next Level
# 5 Weekend
# 6 Permission to Dance
# 7 고백
# 8 좋아좋아
# 9 Butter
# 10 OHAYO MY NIGHT
# 11 Bad Habits
# 12 비가 오는 날엔 (2021)
# 13 Peaches (Feat. Daniel Caesar & Giveon)
# 14 헤픈 우연
# 15 치맛바람 (Chi Mat Ba Ram)
# 16 라일락
# 17 비와 당신
# 18 롤린 (Rollin')
# 19 Dynamite
# 20 하루만 더
# 21 Celebrity
# 22 Dun Dun Dance
# 23 둘 중에 골라 (Summer or Summer)
# 24 Alcohol-Free
# 25 운전만해 (We Ride)
# 26 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 27 DUMB DUMB
# 28 Stay
# 29 다정히 내 이름을 부르면
# 30 나를 아는 사람
# 31 안녕 (Hello)
# 32 이제 나만 믿어요
# 33 Savage Love (Laxed - Siren Beat) (BTS Remix)
# 34 상상더하기
# 35 ASAP
# 36 Timeless
# 37 추적이는 여름 비가 되어
# 38 사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)
# 39 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 40 상상더하기
# 41 내 손을 잡아
# 42 다시 사랑한다면 (김필 Ver.)
# 43 슈퍼스타
# 44 별빛 같은 나의 사랑아
# 45 HERO
# 46 At My Worst
# 47 에잇 (Prod. & Feat. SUGA of BTS)
# 48 전쟁터 (With 이선희)
# 49 아로하
# 50 Off My Face

# %%
# 아티스트 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210806&hh=21&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')

    # 순위에 표시되는 가수 이름은 'class' 속성이 'artist ellipsis'인 <a> 태그 내부에 있다.
    # 순위가 표시되는 매 페이지 상단에 출력되는 그래프에 사용되는 가수 이름도 순위 표시에 사용되는 가수 이름과 동일하게
    # 'class' 속성이 'artist ellipsis'인 <a> 태그 내부에 있기 때문에 가수 이름을 크롤링하면 55개씩 크롤링된다.
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    # print(artists)
    # print(len(artists))
    
    i = 0
    for artist in artists[5:]:
        i += 1
        # print(i, artist.text.strip())
        # print(i, artist.text.split('\n')[-1].strip())
        print(i, artist.text.strip().split('\n')[0])
# Out:
# 1 이무진
# 2 AKMU (악뮤)
# 3 MSG워너비 (M.O.M)
# 4 aespa
# 5 태연 (TAEYEON)
# 6 방탄소년단
# 7 10CM
# 8 조정석
# 9 방탄소년단
# 10 디핵 (D-Hack) & PATEKO
# 11 Ed Sheeran
# 12 헤이즈 (Heize)
# 13 Justin Bieber
# 14 헤이즈 (Heize)
# 15 브레이브걸스 (Brave girls)
# 16 아이유 (IU)
# 17 이무진
# 18 브레이브걸스 (Brave girls)
# 19 방탄소년단
# 20 빅마마 (Big Mama)
# 21 아이유 (IU)
# 22 오마이걸 (OH MY GIRL)
# 23 효린 & 다솜
# 24 TWICE (트와이스)
# 25 브레이브걸스 (Brave girls)
# 26 에픽하이 (EPIK HIGH)
# 27 전소미
# 28 The Kid LAROI & Justin Bieber
# 29 경서예지 & 전건호
# 30 MSG워너비 (정상동기)
# 31 조이 (JOY)
# 32 임영웅
# 33 Jawsh 685 & Jason Derulo & 방탄소년단
# 34 라붐 (LABOUM)
# 35 STAYC (스테이씨)
# 36 SG워너비
# 37 장범준
# 38 호미들
# 39 방탄소년단
# 40 MSG워너비
# 41 아이유 (IU)
# 42 임영웅
# 43 미도와 파라솔
# 44 임영웅
# 45 임영웅
# 46 Pink Sweat$
# 47 아이유 (IU)
# 48 AKMU (악뮤)
# 49 조정석
# 50 Justin Bieber

# %%
# 크롤링한 데이터를 리스트에 저장한다.
genie = []
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210806&hh=21&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 5):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    time.sleep(1)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    
    # genie 리스트에 노래 제목과 가수 이름을 튜플로 만들어 저장한다.
    for j in range(len(titles)):
        genie.append(
            (titles[j].text.strip().split('\n')[0], artists[j].text.strip().split('\n')[0])
        )
# ===== for i in range(1, 5)
print(len(genie))
print(genie)
# Out:
# 200
# [('신호등', '이무진'), ('낙하 (With 아이유)', 'AKMU (악뮤)'), ('바라만 본다', 'MSG워너비 (M.O.M)'), ('Next Level', 'aespa'), ('Weekend', '태연 (TAEYEON)'), ('Permission to Dance', '이무진'), ('고백', 'AKMU (악뮤)'), ('좋아좋아', 'MSG워너비 (M.O.M)'), ('Butter', 'aespa'), ('OHAYO MY NIGHT', '태연 (TAEYEON)'), ('Bad Habits', '방탄소년단'), ('비가 오는 날엔 (2021)', '10CM'), ('Peaches (Feat. Daniel Caesar & Giveon)', '조정석'), ('헤픈 우연', '방탄소년단'), ('치맛바람 (Chi Mat Ba Ram)', '디핵 (D-Hack) & PATEKO'), ('라일락', 'Ed Sheeran'), ('비와 당신', '헤이즈 (Heize)'), ("롤린 (Rollin')", 'Justin Bieber'), ('Dynamite', '헤이즈 (Heize)'), ('하루만 더', '브레이브걸스 (Brave girls)'), ('Celebrity', '아이유 (IU)'), ('Dun Dun Dance', '이무진'), ('둘 중에 골라 (Summer or Summer)', '브레이브걸스 (Brave girls)'), ('Alcohol-Free', '방탄소년단'), ('운전만해 (We Ride)', '빅마마 (Big Mama)'), ('비 오는 날 듣기 좋은 노래 (Feat. Colde)', '아이유 (IU)'), ('DUMB DUMB', '오마이걸 (OH MY GIRL)'), ('Stay', '효린 & 다솜'), ('다정히 내 이름을 부르면', 'TWICE (트와이스)'), ('나를 아는 사람', '브레이브걸스 (Brave girls)'), ('안녕 (Hello)', '에픽하이 (EPIK HIGH)'), ('이제 나만 믿어요', '전소미'), ('Savage Love (Laxed - Siren Beat) (BTS Remix)', 'The Kid LAROI & Justin Bieber'), ('상상더하기', '경서예지 & 전건호'), ('ASAP', 'MSG워너비 (정상동기)'), ('Timeless', '조이 (JOY)'), ('추적이는 여름 비가 되어', '임영웅'), ('사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)', 'Jawsh 685 & Jason Derulo & 방탄소년단'), ('작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)', '라붐 (LABOUM)'), ('상상더하기', 'STAYC (스테이씨)'), ('내 손을 잡아', 'SG워너비'), ('다시 사랑한다면 (김필 Ver.)', '장범준'), ('슈퍼스타', '호미들'), ('별빛 같은 나의 사랑아', '방탄소년단'), ('HERO', 'MSG워너비'), ('At My Worst', '아이유 (IU)'), ('에잇 (Prod. & Feat. SUGA of BTS)', '임영웅'), ('전쟁터 (With 이선희)', '미도와 파라솔'), ('아로하', '임영웅'), ('Off My Face', '임영웅'), ('넌 좋은 사람', '이무진'), ('러브 (Prod. by 로코베리)', 'AKMU (악뮤)'), ('Lovesick Girls', 'MSG워너비 (M.O.M)'), ('이젠 잊기로 해요 (Drama Ver.)', 'aespa'), ('2002', '태연 (TAEYEON)'), ('어푸 (Ah puh)', 'SG워너비'), ('Life Goes On', '로꼬 & 이성경'), ('Blueming', 'BLACKPINK'), ('멜로디', '미도와 파라솔'), ('가을 우체국 앞에서', 'Anne-Marie'), ('밝게 빛나는 별이 되어 비춰줄게', '아이유 (IU)'), ('은하수를 닮은 너에게 (Feat. 몰리디)', '방탄소년단'), ('Coin', '아이유 (IU)'), ('봄날', 'ASH ISLAND'), ('그대라는 사치', '김대명'), ('흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야', '송이한'), ('끝사랑', '경서예지'), ('밤이 되니까', '아이유 (IU)'), ('Bk Love', '방탄소년단'), ('고백', '임영웅'), ('METEOR', '장범준'), ('LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)', '임영웅'), ('나는 너 좋아', '원슈타인'), ('12 : 45 (Stripped)', '임영웅'), ('Dolphin', '장범준'), ('밤하늘의 별을 (2020)', '창모 (CHANGMO)'), ('Kiss Me More (Feat. SZA)', '양요섭 & 정은지'), ("You can't sit with us", '장범준'), ('라라라', 'etham'), ('VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)', '오마이걸 (OH MY GIRL)'), ('여행', '경서'), ('째깍 째깍 째깍 (With Beenzino)', 'Doja Cat'), ('어떻게 이별까지 사랑하겠어, 널 사랑하는 거지', '선미'), ('미워요', 'SG워너비'), ('오래된 노래', '미란이 (Mirani) & 먼치맨 (MUNCHMAN) & Khundi Panda & 머쉬베놈 (MUSHVENOM)'), ('모든 날, 모든 순간 (Every day, Every Moment)', '볼빨간사춘기'), ('좋은 사람 있으면 소개시켜줘', 'AKMU (악뮤)'), ('잠이 오질 않네요', 'AKMU (악뮤)'), ('THRILL RIDE', '임영웅'), ('Leave The Door Open', 'Standing Egg (스탠딩 에그)'), ('허리춤', '폴킴'), ('너무 보고싶어', '조이 (JOY)'), ('parachute', '장범준'), ('Memories', '더보이즈 (THE BOYZ)'), ('Dance Monkey', 'Bruno Mars & Anderson .Paak & Silk Sonic'), ('잊었니', '오반 (OVAN)'), ('다시 여기 바닷가', '전상근'), ('취기를 빌려 (취향저격 그녀 X 산들)', 'John K'), ('다시 사랑할 수 있을까', 'Maroon 5'), ('BENCH (With Zion.T)', 'Tones And I'), ('ON', '이무진'), ('그날에 나는 맘이 편했을까', 'AKMU (악뮤)'), ('Tiny Riot', 'MSG워너비 (M.O.M)'), ('오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)', 'aespa'), ('계단말고 엘리베이터', '태연 (TAEYEON)'), ('마.피.아. In the morning', '방탄소년단'), ('Way Back Home', '이예준'), ('사랑하게 될 줄 알았어', 'Sam Ryder'), ('벌써 일년 (Drama Ver.)', '마크툽 (Maktub)'), ('사랑의 아픔 딛고', '임영웅'), ('DNA', 'ITZY (있지)'), ('난 너를 사랑해', '숀 (SHAUN)'), ('소우주 (Mikrokosmos)', '전미도'), ('Leave Before You Love Me', '미도와 파라솔'), ('Rainy day (Feat. ASH ISLAND & Skinny Brown)', '임영웅'), ('On The Ground', '방탄소년단'), ('사이렌', 'MSG워너비'), ('살짝 설렜어 (Nonstop)', '방탄소년단'), ("Don't Start Now", 'Marshmello & Jonas Brothers'), ('추억은 만남보다 이별에 남아', 'PATEKO (파테코)'), ('우린 어쩌다 헤어진 걸까', '로제 (ROSE)'), ('IDOL', '호미들'), ('너에게', '오마이걸 (OH MY GIRL)'), ('너의 번호를 누르고 (Prod. by 영화처럼)', 'Dua Lipa'), ('내사람 : Partn ...

# %%
print(dt.now())
for i in range(len(genie)):
    print('{0:3d}위 {1} - {2}'.format(i + 1, genie[i][1], genie[i][0]))
# Out:
# 2021-08-10 19:36:55.388901
#   1위 이무진 - 신호등
#   2위 AKMU (악뮤) - 낙하 (With 아이유)
#   3위 MSG워너비 (M.O.M) - 바라만 본다
#   4위 aespa - Next Level
#   5위 태연 (TAEYEON) - Weekend
#   6위 이무진 - Permission to Dance
#   7위 AKMU (악뮤) - 고백
#   8위 MSG워너비 (M.O.M) - 좋아좋아
#   9위 aespa - Butter
#  10위 태연 (TAEYEON) - OHAYO MY NIGHT
#  11위 방탄소년단 - Bad Habits
#  12위 10CM - 비가 오는 날엔 (2021)
#  13위 조정석 - Peaches (Feat. Daniel Caesar & Giveon)
#  14위 방탄소년단 - 헤픈 우연
#  15위 디핵 (D-Hack) & PATEKO - 치맛바람 (Chi Mat Ba Ram)
#  16위 Ed Sheeran - 라일락
#  17위 헤이즈 (Heize) - 비와 당신
#  18위 Justin Bieber - 롤린 (Rollin')
#  19위 헤이즈 (Heize) - Dynamite
#  20위 브레이브걸스 (Brave girls) - 하루만 더
#  21위 아이유 (IU) - Celebrity
#  22위 이무진 - Dun Dun Dance
#  23위 브레이브걸스 (Brave girls) - 둘 중에 골라 (Summer or Summer)
#  24위 방탄소년단 - Alcohol-Free
#  25위 빅마마 (Big Mama) - 운전만해 (We Ride)
#  26위 아이유 (IU) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  27위 오마이걸 (OH MY GIRL) - DUMB DUMB
#  28위 효린 & 다솜 - Stay
#  29위 TWICE (트와이스) - 다정히 내 이름을 부르면
#  30위 브레이브걸스 (Brave girls) - 나를 아는 사람
#  31위 에픽하이 (EPIK HIGH) - 안녕 (Hello)
#  32위 전소미 - 이제 나만 믿어요
#  33위 The Kid LAROI & Justin Bieber - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  34위 경서예지 & 전건호 - 상상더하기
#  35위 MSG워너비 (정상동기) - ASAP
#  36위 조이 (JOY) - Timeless
#  37위 임영웅 - 추적이는 여름 비가 되어
#  38위 Jawsh 685 & Jason Derulo & 방탄소년단 - 사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)
#  39위 라붐 (LABOUM) - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  40위 STAYC (스테이씨) - 상상더하기
#  41위 SG워너비 - 내 손을 잡아
#  42위 장범준 - 다시 사랑한다면 (김필 Ver.)
#  43위 호미들 - 슈퍼스타
#  44위 방탄소년단 - 별빛 같은 나의 사랑아
#  45위 MSG워너비 - HERO
#  46위 아이유 (IU) - At My Worst
#  47위 임영웅 - 에잇 (Prod. & Feat. SUGA of BTS)
#  48위 미도와 파라솔 - 전쟁터 (With 이선희)
#  49위 임영웅 - 아로하
#  50위 임영웅 - Off My Face
#  51위 이무진 - 넌 좋은 사람
#  52위 AKMU (악뮤) - 러브 (Prod. by 로코베리)
#  53위 MSG워너비 (M.O.M) - Lovesick Girls
#  54위 aespa - 이젠 잊기로 해요 (Drama Ver.)
#  55위 태연 (TAEYEON) - 2002
#  56위 SG워너비 - 어푸 (Ah puh)
#  57위 로꼬 & 이성경 - Life Goes On
#  58위 BLACKPINK - Blueming
#  59위 미도와 파라솔 - 멜로디
#  60위 Anne-Marie - 가을 우체국 앞에서
#  61위 아이유 (IU) - 밝게 빛나는 별이 되어 비춰줄게
#  62위 방탄소년단 - 은하수를 닮은 너에게 (Feat. 몰리디)
#  63위 아이유 (IU) - Coin
#  64위 ASH ISLAND - 봄날
#  65위 김대명 - 그대라는 사치
#  66위 송이한 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  67위 경서예지 - 끝사랑
#  68위 아이유 (IU) - 밤이 되니까
#  69위 방탄소년단 - Bk Love
#  70위 임영웅 - 고백
#  71위 장범준 - METEOR
#  72위 임영웅 - LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
#  73위 원슈타인 - 나는 너 좋아
#  74위 임영웅 - 12 : 45 (Stripped)
#  75위 장범준 - Dolphin
#  76위 창모 (CHANGMO) - 밤하늘의 별을 (2020)
#  77위 양요섭 & 정은지 - Kiss Me More (Feat. SZA)
#  78위 장범준 - You can't sit with us
#  79위 etham - 라라라
#  80위 오마이걸 (OH MY GIRL) - VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)
#  81위 경서 - 여행
#  82위 Doja Cat - 째깍 째깍 째깍 (With Beenzino)
#  83위 선미 - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  84위 SG워너비 - 미워요
#  85위 미란이 (Mirani) & 먼치맨 (MUNCHMAN) & Khundi Panda & 머쉬베놈 (MUSHVENOM) - 오래된 노래
#  86위 볼빨간사춘기 - 모든 날, 모든 순간 (Every day, Every Moment)
#  87위 AKMU (악뮤) - 좋은 사람 있으면 소개시켜줘
#  88위 AKMU (악뮤) - 잠이 오질 않네요
#  89위 임영웅 - THRILL RIDE
#  90위 Standing Egg (스탠딩 에그) - Leave The Door Open
#  91위 폴킴 - 허리춤
#  92위 조이 (JOY) - 너무 보고싶어
#  93위 장범준 - parachute
#  94위 더보이즈 (THE BOYZ) - Memories
#  95위 Bruno Mars & Anderson .Paak & Silk Sonic - Dance Monkey
#  96위 오반 (OVAN) - 잊었니
#  97위 전상근 - 다시 여기 바닷가
#  98위 John K - 취기를 빌려 (취향저격 그녀 X 산들)
#  99위 Maroon 5 - 다시 사랑할 수 있을까
# 100위 Tones And I - BENCH (With Zion.T)
# 101위 이무진 - ON
# 102위 AKMU (악뮤) - 그날에 나는 맘이 편했을까
# 103위 MSG워너비 (M.O.M) - Tiny Riot
# 104위 aespa - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 105위 태연 (TAEYEON) - 계단말고 엘리베이터
# 106위 방탄소년단 - 마.피.아. In the morning
# 107위 이예준 - Way Back Home
# 108위 Sam Ryder - 사랑하게 될 줄 알았어
# 109위 마크툽 (Maktub) - 벌써 일년 (Drama Ver.)
# 110위 임영웅 - 사랑의 아픔 딛고
# 111위 ITZY (있지) - DNA
# 112위 숀 (SHAUN) - 난 너를 사랑해
# 113위 전미도 - 소우주 (Mikrokosmos)
# 114위 미도와 파라솔 - Leave Before You Love Me
# 115위 임영웅 - Rainy day (Feat. ASH ISLAND & Skinny Brown)
# 116위 방탄소년단 - On The Ground
# 117위 MSG워너비 - 사이렌
# 118위 방탄소년단 - 살짝 설렜어 (Nonstop)
# 119위 Marshmello & Jonas Brothers - Don't Start Now
# 120위 PATEKO (파테코) - 추억은 만남보다 이별에 남아
# 121위 로제 (ROSE) - 우린 어쩌다 헤어진 걸까
# 122위 호미들 - IDOL
# 123위 오마이걸 (OH MY GIRL) - 너에게
# 124위 Dua Lipa - 너의 번호를 누르고 (Prod. by 영화처럼)
# 125위 정동하 - 내사람 : Partner For Life
# 126위 허각 - 늦은 밤 너의 집 앞 골목길에서
# 127위 방탄소년단 - Ashes
# 128위 유연석 - 목로주점
# 129위 #안녕 - 어떻게 지내 (Prod. by VAN.C)
# 130위 SG워너비 - Way Back Home (2021)
# 131위 노을 - Bad
# 132위 Stellar - 그냥 안아달란 말야
# 133위 임영웅 - Bad Boy
# 134위 오반 (OVAN) - 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)
# 135위 런치 - Stupid love song (With Crush)
# 136위 Christopher - 사실 나는 (Feat. 전건호)
# 137위 다비치 - FAKE LOVE
# 138위 청하 & Christopher - Shape Of You
# 139위 10CM - Black Mamba
# 140위 AKMU (악뮤) - 주저하는 연인들을 위해
# 141위 경서예지 - I Don't Love You (Feat. 쿠기)
# 142위 방탄소년단 - 안녕
# 143위 Ed Sheeran - 여름 쏙 (Popping)
# 144위 aespa - 밤편지
# 145위 잔나비 - 마음을 드려요
# 146위 GRAY (그레이) - Paris In The Rain
# 147위 폴킴 - 시작
# 148위 온앤오프 (ONF) - 비도 오고 그래서 (Feat. 신용재)
# 149위 아이유 (IU) - How You Like That
# 150위 아이유 (IU) - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 151위 이무진 - 밤하늘의 저 별처럼
# 152위 AKMU (악뮤) - 불타오르네 (FIRE)
# 153위 MSG워너비 (M.O.M) - Maniac
# 154위 aespa - 해야 해
# 155위 태연 (TAEYEON) - 너의 발걸음에 빛을 비춰줄게 (Prod. by 조영수)
# 156위 헤이즈 (Heize) & 펀치 (Punch) - 내 입술 따뜻한 커피처럼
# 157위 방탄소년단 - 체념
# 158위 Conan Gray - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 159위 2PM - 우리집
# 160위 케이시 (Kassy) - 만개 (Prod. 신지후)
# 161위 청하 & Colde (콜드) - 너의 모든 순간
# 162위 MSG워너비 (정상동기) - 사계 (Four Seasons)
# 163위 규현 (KYUHYUN) - BLUE MOON (Prod. by GroovyRoom)
# 164위 2PM - 힘든 건 사랑이 아니다
# 165위 김호중 - 아무노래
# 166위 성시경 - On My Way
# 167위 태연 (TAEYEON) - 한여름밤의 꿀 : 다시 여름
# 168위 효린 & 창모 (CHANGMO) - All Falls Down (Feat. Juliander)
# 169위 임창정 - 나보다 더 사랑해요
# 170위 지코 (ZICO) - Stuck With U
# 171위 Alan Walker & Sabrina Carpenter & Farruko - bad guy
# 172위 San E & 레이나 - 고백 (바른연애 길잡이 X 허각)
# 173위 Alan Walker & Noah Cyrus & Digital Farm Animals - Comethru
# 174위 김호중 - 제주도의 푸른 밤
# 175위 Ariana Grande & Justin Bieber - Love poem
# 176위 Billie Eilish - WE GO
# 177위 허각 - 살다가
# 178위 Jeremy Zucker - 보고 싶단 말이야
# 179위 태연 (TAEYEON) - 너를 만나
# 180위 아이유 (IU) - Downtown Baby
# 181위 프로미스나인 - 술 한잔 해요
# 182위 SG워너비 - EVEREST (With Sam Kim)
# 183위 펀치 (Punch) & 매드 클라운 (Mad Clown) - 고맙소
# 184위 폴킴 - 첫눈처럼 너에게 가겠다
# 185위 블루 (BLOO) - Rose
# 186위 경서 (경서예지) & MJ (써니사이드) - 환상열차 (Out Of Control)
# 187위 AKMU (악뮤) - Dancing Till We Drop
# 188위 김호중 - Merry Bad Ending
# 189위 에일리 (AILEE) - 화려하지 않은 고백
# 190위 디오 (D.O.) - Painkiller
# 191위 더보이즈 (THE BOYZ) - 노래방에서
# 192위 더보이즈 (THE BOYZ) - 살았소
# 193위 더보이즈 (THE BOYZ) - Psycho
# 194위 규현 (KYUHYUN) - Nightmares (黑花)
# 195위 Ruel - 맞짱 (With 잔나비 최정훈)
# 196위 장범준 - After Midnight
# 197위 김호중 - I'm Gonna Love You (Feat. 원슈타인)
# 198위 Red Velvet (레드벨벳) - Hello Future
# 199위 더보이즈 (THE BOYZ) - B.O.Y (Bet On You)
# 200위 AKMU (악뮤) - 맛 (Hot Sauce)

# %%
# 크롤링한 결과를 텍스트 파일에 저장한다.
file = open('./data/genieTOP200.txt', 'w')
file.write('{} 현재 Genie 뮤직 실시간 TOP 100\n'.format(dt.now()))
for i in range(len(genie)):
    data = '{0:3d}위 {1} - {2}'.format(i + 1, genie[i][1], genie[i][0])
    file.write(data + '\n')
file.close()
print('genieTOP200.txt 파일에 쓰기 완료')
# Out:
# genieTOP200.txt 파일에 쓰기 완료

# %%
# 텍스트 파일에 저장된 데이터를 읽어서 출력한다.
try:
    file = open('./data/genieTOP200.txt', 'r')
    lines = file.readlines()
    for line in lines:
        print(line.strip())
except FileNotFoundError:
    print('genieTOP200.txt 파일이 디스크에 없습니다.')
# Out:
# 2021-08-10 19:40:36.468041 현재 Genie 뮤직 실시간 TOP 100
# 1위 이무진 - 신호등
# 2위 AKMU (악뮤) - 낙하 (With 아이유)
# 3위 MSG워너비 (M.O.M) - 바라만 본다
# 4위 aespa - Next Level
# 5위 태연 (TAEYEON) - Weekend
# 6위 이무진 - Permission to Dance
# 7위 AKMU (악뮤) - 고백
# 8위 MSG워너비 (M.O.M) - 좋아좋아
# 9위 aespa - Butter
# 10위 태연 (TAEYEON) - OHAYO MY NIGHT
# 11위 방탄소년단 - Bad Habits
# 12위 10CM - 비가 오는 날엔 (2021)
# 13위 조정석 - Peaches (Feat. Daniel Caesar & Giveon)
# 14위 방탄소년단 - 헤픈 우연
# 15위 디핵 (D-Hack) & PATEKO - 치맛바람 (Chi Mat Ba Ram)
# 16위 Ed Sheeran - 라일락
# 17위 헤이즈 (Heize) - 비와 당신
# 18위 Justin Bieber - 롤린 (Rollin')
# 19위 헤이즈 (Heize) - Dynamite
# 20위 브레이브걸스 (Brave girls) - 하루만 더
# 21위 아이유 (IU) - Celebrity
# 22위 이무진 - Dun Dun Dance
# 23위 브레이브걸스 (Brave girls) - 둘 중에 골라 (Summer or Summer)
# 24위 방탄소년단 - Alcohol-Free
# 25위 빅마마 (Big Mama) - 운전만해 (We Ride)
# 26위 아이유 (IU) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 27위 오마이걸 (OH MY GIRL) - DUMB DUMB
# 28위 효린 & 다솜 - Stay
# 29위 TWICE (트와이스) - 다정히 내 이름을 부르면
# 30위 브레이브걸스 (Brave girls) - 나를 아는 사람
# 31위 에픽하이 (EPIK HIGH) - 안녕 (Hello)
# 32위 전소미 - 이제 나만 믿어요
# 33위 The Kid LAROI & Justin Bieber - Savage Love (Laxed - Siren Beat) (BTS Remix)
# 34위 경서예지 & 전건호 - 상상더하기
# 35위 MSG워너비 (정상동기) - ASAP
# 36위 조이 (JOY) - Timeless
# 37위 임영웅 - 추적이는 여름 비가 되어
# 38위 Jawsh 685 & Jason Derulo & 방탄소년단 - 사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)
# 39위 라붐 (LABOUM) - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 40위 STAYC (스테이씨) - 상상더하기
# 41위 SG워너비 - 내 손을 잡아
# 42위 장범준 - 다시 사랑한다면 (김필 Ver.)
# 43위 호미들 - 슈퍼스타
# 44위 방탄소년단 - 별빛 같은 나의 사랑아
# 45위 MSG워너비 - HERO
# 46위 아이유 (IU) - At My Worst
# 47위 임영웅 - 에잇 (Prod. & Feat. SUGA of BTS)
# 48위 미도와 파라솔 - 전쟁터 (With 이선희)
# 49위 임영웅 - 아로하
# 50위 임영웅 - Off My Face
# 51위 이무진 - 넌 좋은 사람
# 52위 AKMU (악뮤) - 러브 (Prod. by 로코베리)
# 53위 MSG워너비 (M.O.M) - Lovesick Girls
# 54위 aespa - 이젠 잊기로 해요 (Drama Ver.)
# 55위 태연 (TAEYEON) - 2002
# 56위 SG워너비 - 어푸 (Ah puh)
# 57위 로꼬 & 이성경 - Life Goes On
# 58위 BLACKPINK - Blueming
# 59위 미도와 파라솔 - 멜로디
# 60위 Anne-Marie - 가을 우체국 앞에서
# 61위 아이유 (IU) - 밝게 빛나는 별이 되어 비춰줄게
# 62위 방탄소년단 - 은하수를 닮은 너에게 (Feat. 몰리디)
# 63위 아이유 (IU) - Coin
# 64위 ASH ISLAND - 봄날
# 65위 김대명 - 그대라는 사치
# 66위 송이한 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 67위 경서예지 - 끝사랑
# 68위 아이유 (IU) - 밤이 되니까
# 69위 방탄소년단 - Bk Love
# 70위 임영웅 - 고백
# 71위 장범준 - METEOR
# 72위 임영웅 - LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
# 73위 원슈타인 - 나는 너 좋아
# 74위 임영웅 - 12 : 45 (Stripped)
# 75위 장범준 - Dolphin
# 76위 창모 (CHANGMO) - 밤하늘의 별을 (2020)
# 77위 양요섭 & 정은지 - Kiss Me More (Feat. SZA)
# 78위 장범준 - You can't sit with us
# 79위 etham - 라라라
# 80위 오마이걸 (OH MY GIRL) - VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)
# 81위 경서 - 여행
# 82위 Doja Cat - 째깍 째깍 째깍 (With Beenzino)
# 83위 선미 - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 84위 SG워너비 - 미워요
# 85위 미란이 (Mirani) & 먼치맨 (MUNCHMAN) & Khundi Panda & 머쉬베놈 (MUSHVENOM) - 오래된 노래
# 86위 볼빨간사춘기 - 모든 날, 모든 순간 (Every day, Every Moment)
# 87위 AKMU (악뮤) - 좋은 사람 있으면 소개시켜줘
# 88위 AKMU (악뮤) - 잠이 오질 않네요
# 89위 임영웅 - THRILL RIDE
# 90위 Standing Egg (스탠딩 에그) - Leave The Door Open
# 91위 폴킴 - 허리춤
# 92위 조이 (JOY) - 너무 보고싶어
# 93위 장범준 - parachute
# 94위 더보이즈 (THE BOYZ) - Memories
# 95위 Bruno Mars & Anderson .Paak & Silk Sonic - Dance Monkey
# 96위 오반 (OVAN) - 잊었니
# 97위 전상근 - 다시 여기 바닷가
# 98위 John K - 취기를 빌려 (취향저격 그녀 X 산들)
# 99위 Maroon 5 - 다시 사랑할 수 있을까
# 100위 Tones And I - BENCH (With Zion.T)
# 101위 이무진 - ON
# 102위 AKMU (악뮤) - 그날에 나는 맘이 편했을까
# 103위 MSG워너비 (M.O.M) - Tiny Riot
# 104위 aespa - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 105위 태연 (TAEYEON) - 계단말고 엘리베이터
# 106위 방탄소년단 - 마.피.아. In the morning
# 107위 이예준 - Way Back Home
# 108위 Sam Ryder - 사랑하게 될 줄 알았어
# 109위 마크툽 (Maktub) - 벌써 일년 (Drama Ver.)
# 110위 임영웅 - 사랑의 아픔 딛고
# 111위 ITZY (있지) - DNA
# 112위 숀 (SHAUN) - 난 너를 사랑해
# 113위 전미도 - 소우주 (Mikrokosmos)
# 114위 미도와 파라솔 - Leave Before You Love Me
# 115위 임영웅 - Rainy day (Feat. ASH ISLAND & Skinny Brown)
# 116위 방탄소년단 - On The Ground
# 117위 MSG워너비 - 사이렌
# 118위 방탄소년단 - 살짝 설렜어 (Nonstop)
# 119위 Marshmello & Jonas Brothers - Don't Start Now
# 120위 PATEKO (파테코) - 추억은 만남보다 이별에 남아
# 121위 로제 (ROSE) - 우린 어쩌다 헤어진 걸까
# 122위 호미들 - IDOL
# 123위 오마이걸 (OH MY GIRL) - 너에게
# 124위 Dua Lipa - 너의 번호를 누르고 (Prod. by 영화처럼)
# 125위 정동하 - 내사람 : Partner For Life
# 126위 허각 - 늦은 밤 너의 집 앞 골목길에서
# 127위 방탄소년단 - Ashes
# 128위 유연석 - 목로주점
# 129위 #안녕 - 어떻게 지내 (Prod. by VAN.C)
# 130위 SG워너비 - Way Back Home (2021)
# 131위 노을 - Bad
# 132위 Stellar - 그냥 안아달란 말야
# 133위 임영웅 - Bad Boy
# 134위 오반 (OVAN) - 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)
# 135위 런치 - Stupid love song (With Crush)
# 136위 Christopher - 사실 나는 (Feat. 전건호)
# 137위 다비치 - FAKE LOVE
# 138위 청하 & Christopher - Shape Of You
# 139위 10CM - Black Mamba
# 140위 AKMU (악뮤) - 주저하는 연인들을 위해
# 141위 경서예지 - I Don't Love You (Feat. 쿠기)
# 142위 방탄소년단 - 안녕
# 143위 Ed Sheeran - 여름 쏙 (Popping)
# 144위 aespa - 밤편지
# 145위 잔나비 - 마음을 드려요
# 146위 GRAY (그레이) - Paris In The Rain
# 147위 폴킴 - 시작
# 148위 온앤오프 (ONF) - 비도 오고 그래서 (Feat. 신용재)
# 149위 아이유 (IU) - How You Like That
# 150위 아이유 (IU) - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 151위 이무진 - 밤하늘의 저 별처럼
# 152위 AKMU (악뮤) - 불타오르네 (FIRE)
# 153위 MSG워너비 (M.O.M) - Maniac
# 154위 aespa - 해야 해
# 155위 태연 (TAEYEON) - 너의 발걸음에 빛을 비춰줄게 (Prod. by 조영수)
# 156위 헤이즈 (Heize) & 펀치 (Punch) - 내 입술 따뜻한 커피처럼
# 157위 방탄소년단 - 체념
# 158위 Conan Gray - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 159위 2PM - 우리집
# 160위 케이시 (Kassy) - 만개 (Prod. 신지후)
# 161위 청하 & Colde (콜드) - 너의 모든 순간
# 162위 MSG워너비 (정상동기) - 사계 (Four Seasons)
# 163위 규현 (KYUHYUN) - BLUE MOON (Prod. by GroovyRoom)
# 164위 2PM - 힘든 건 사랑이 아니다
# 165위 김호중 - 아무노래
# 166위 성시경 - On My Way
# 167위 태연 (TAEYEON) - 한여름밤의 꿀 : 다시 여름
# 168위 효린 & 창모 (CHANGMO) - All Falls Down (Feat. Juliander)
# 169위 임창정 - 나보다 더 사랑해요
# 170위 지코 (ZICO) - Stuck With U
# 171위 Alan Walker & Sabrina Carpenter & Farruko - bad guy
# 172위 San E & 레이나 - 고백 (바른연애 길잡이 X 허각)
# 173위 Alan Walker & Noah Cyrus & Digital Farm Animals - Comethru
# 174위 김호중 - 제주도의 푸른 밤
# 175위 Ariana Grande & Justin Bieber - Love poem
# 176위 Billie Eilish - WE GO
# 177위 허각 - 살다가
# 178위 Jeremy Zucker - 보고 싶단 말이야
# 179위 태연 (TAEYEON) - 너를 만나
# 180위 아이유 (IU) - Downtown Baby
# 181위 프로미스나인 - 술 한잔 해요
# 182위 SG워너비 - EVEREST (With Sam Kim)
# 183위 펀치 (Punch) & 매드 클라운 (Mad Clown) - 고맙소
# 184위 폴킴 - 첫눈처럼 너에게 가겠다
# 185위 블루 (BLOO) - Rose
# 186위 경서 (경서예지) & MJ (써니사이드) - 환상열차 (Out Of Control)
# 187위 AKMU (악뮤) - Dancing Till We Drop
# 188위 김호중 - Merry Bad Ending
# 189위 에일리 (AILEE) - 화려하지 않은 고백
# 190위 디오 (D.O.) - Painkiller
# 191위 더보이즈 (THE BOYZ) - 노래방에서
# 192위 더보이즈 (THE BOYZ) - 살았소
# 193위 더보이즈 (THE BOYZ) - Psycho
# 194위 규현 (KYUHYUN) - Nightmares (黑花)
# 195위 Ruel - 맞짱 (With 잔나비 최정훈)
# 196위 장범준 - After Midnight
# 197위 김호중 - I'm Gonna Love You (Feat. 원슈타인)
# 198위 Red Velvet (레드벨벳) - Hello Future
# 199위 더보이즈 (THE BOYZ) - B.O.Y (Bet On You)
# 200위 AKMU (악뮤) - 맛 (Hot Sauce)
